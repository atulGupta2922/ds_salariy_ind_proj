# %%
import pandas as pd

# %%
data = pd.read_csv('glassdoor_ds_jobs.csv')
data.head()
# Out:
#                          Job Title                     Salary Estimate  \
# 0   Intern - Data Science Engineer                                  -1
# 1  Assistant Data Science Engineer  Employer Provided Salary:₹7L - ₹8L
# 2                   Data Scientist          ₹6L - ₹8L (Glassdoor Est.)
# 3          Data Science Internship                                  -1
# 4                   Data Analytics          ₹4L - ₹7L (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Our vision is to transform how the world uses ...     3.7
# 1  Established in 2007, Educate Girls’ is a non-p...     3.9
# 2  About Us\n\nRamSoft is a global leader in Web ...     3.8
# 3  Selected intern's day-to-day responsibilities ...     4.3
# 4  Job Description\n\n\n\n\nDomain\n\n\nData Anal...     3.7
#
#                     Company Name   Location                    Size  Founded  \
# 0                    Micron\n3.7  Hyderābād        10000+ Employees     1978
# 1             Educate Girls\n3.9     Mumbai  1001 to 5000 Employees       -1
# 2                   RamSoft\n3.8  Bengaluru     51 to 200 Employees     1994
# 3                  UpTricks\n4.3       Pune     51 to 200 Employees     2013
# 4  Tata Technologies Europe\n3.7       Pune        10000+ Employees     1989
#
#    Type of ownership                                 Industry  \
# 0   Company - Public            Computer Hardware Development
# 1  Company - Private                                       -1
# 2  Company - Private                     Software Development
# 3      Self-employed  Information Technology Support Services
# 4  Company - Private                   Research & Development
#
#                     Sector                     Revenue  Competitors
# 0   Information Technology          $10+ billion (USD)           -1
# 1                       -1    Unknown / Non-Applicable           -1
# 2   Information Technology    Unknown / Non-Applicable           -1
# 3   Information Technology     $5 to $25 million (USD)           -1
# 4  Management & Consulting  $100 to $500 million (USD)           -1

# %% [markdown]
# ##### Data Cleaning
# - ✅ Salary Parsing
# - ✅ Company Name text only
# - ~~Location Field~~
# - ✅ Age of Company
# - Parsing of Job Description (Python, etc)

# %%
data = data[data['Salary Estimate'] != '-1']

#adding new column for Employer provided salary
data['Employer Provided Salary'] = data['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Employer Provided Salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:4141, in DataFrame._set_item_mgr(self, key, value)
#    4140 try:
# -> 4141     loc = self._info_axis.get_loc(key)
#    4142 except KeyError:
#    4143     # This item wasn't present, just insert at end
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#
# KeyError: 'Employer Provided Salary'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 data = data[data['Salary Estimate'] != '-1']
#       3 #adding new column for Employer provided salary
# ----> 4 data['Employer Provided Salary'] = data['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)
#       5 data.head()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:4187, in DataFrame._set_item(self, key, value)
#    4184         if isinstance(existing_piece, DataFrame):
#    4185             value = np.tile(value, (len(existing_piece.columns), 1)).T
# -> 4187 self._set_item_mgr(key, value)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:4144, in DataFrame._set_item_mgr(self, key, value)
#    4141     loc = self._info_axis.get_loc(key)
#    4142 except KeyError:
#    4143     # This item wasn't present, just insert at end
# -> 4144     self._mgr.insert(len(self._info_axis), key, value)
#    4145 else:
#    4146     self._iset_item_mgr(loc, value)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/managers.py:1425, in BlockManager.insert(self, loc, item, value)
#    1423 else:
#    1424     self._insert_update_mgr_locs(loc)
# -> 1425     self._insert_update_blklocs_and_blknos(loc)
#    1427 self.axes[0] = new_axis
#    1428 self.blocks += (block,)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/managers.py:1464, in BlockManager._insert_update_blklocs_and_blknos(self, loc)
#    1461 # Accessing public blklocs ensures the public versions are initialized
#    1462 if loc == self.blklocs.shape[0]:
#    1463     # np.append is a lot faster, let's use it if we can.
# -> 1464     self._blklocs = np.append(self._blklocs, 0)
#    1465     self._blknos = np.append(self._blknos, len(self.blocks))
#    1466 elif loc == 0:
#    1467     # np.append is a lot faster, let's use it if we can.
#
# File <__array_function__ internals>:180, in append(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:5442, in append(arr, values, axis)
#    5440     if arr.ndim != 1:
#    5441         arr = arr.ravel()
# -> 5442     values = ravel(values)
#    5443     axis = arr.ndim-1
#    5444 return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:180, in ravel(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1856, in ravel(a, order)
#    1755 @array_function_dispatch(_ravel_dispatcher)
#    1756 def ravel(a, order='C'):
#    1757     """Return a contiguous flattened array.
#    1758
#    1759     A 1-D array, containing the elements of the input, is returned.  A copy is
#    (...)
#    1854
#    1855     """
# -> 1856     if isinstance(a, np.matrix):
#    1857         return asarray(a).ravel(order=order)
#    1858     else:
#
# AttributeError: module 'numpy' has no attribute 'matrix'

# %%
# removing text from Salary Estimate
def text_replacements(original: str, replacements: dict):
    for str, replace_with in replacements.items():
        original = original.replace(str, replace_with)
    return original

# %%
replacements = {
    'Employer Provided Salary:': '',
    ' (Glassdoor Est.)': '',
    '₹': ''
}
data['Salary Estimate'] = data['Salary Estimate'].apply(lambda x: text_replacements(x, replacements))

# %%
data.head()
# Out:
#                          Job Title Salary Estimate  \
# 1  Assistant Data Science Engineer         7L - 8L
# 2                   Data Scientist         6L - 8L
# 4                   Data Analytics         4L - 7L
# 5              Data Science Intern       12T - 21T
# 6     A&A -Data Scientist - AI POD         5L - 9L
#
#                                      Job Description  Rating  \
# 1  Established in 2007, Educate Girls’ is a non-p...     3.9
# 2  About Us\n\nRamSoft is a global leader in Web ...     3.8
# 4  Job Description\n\n\n\n\nDomain\n\n\nData Anal...     3.7
# 5  ABOUT COTO\ncoto is a strong, growing deep tec...     4.3
# 6  Data Scientist- Staff\nDo you have a passion f...     4.1
#
#                     Company Name   Location                    Size  Founded  \
# 1             Educate Girls\n3.9     Mumbai  1001 to 5000 Employees       -1
# 2                   RamSoft\n3.8  Bengaluru     51 to 200 Employees     1994
# 4  Tata Technologies Europe\n3.7       Pune        10000+ Employees     1989
# 5                      Coto\n4.3     Mumbai     51 to 200 Employees     2021
# 6                  Deloitte\n4.1  Bengaluru        10000+ Employees     1850
#
#    Type of ownership                Industry                   Sector  \
# 1  Company - Private                      -1                       -1
# 2  Company - Private    Software Development   Information Technology
# 4  Company - Private  Research & Development  Management & Consulting
# 5  Company - Private    Software Development   Information Technology
# 6  Company - Private        Accounting & Tax                  Finance
#
#                       Revenue  Competitors  Employer Provided Salary
# 1    Unknown / Non-Applicable           -1                         1
# 2    Unknown / Non-Applicable           -1                         0
# 4  $100 to $500 million (USD)           -1                         0
# 5    Unknown / Non-Applicable           -1                         1
# 6    Unknown / Non-Applicable           -1                         0

# %%
data['Salary Estimate'].value_counts()
# Out:
# 4L - 8L      3
# 5L - 9L      3
# 5L - 8L      3
# 6L - 8L      3
# 6L - 9L      3
# 4L - 7L      2
# 5L - 7L      2
# 18L - 25L    1
# 2L           1
# 8L - 9L      1
# 7L - 7L      1
# 4L - 5L      1
# 1L           1
# 29L          1
# 7L - 8L      1
# 2L - 3L      1
# 1L - 10L     1
# 6L - 7L      1
# 4L - 10L     1
# 71L - 1Cr    1
# 4L           1
# 12T - 21T    1
# 9L           1
# Name: Salary Estimate, dtype: int64

# %%
def get_avg_salary_in_lakhs(salary_str: str) -> int:
    min_sal, max_sal, avg_sal = 0,0,0
    if '-' in salary_str:
        min_sal = get_number_in_lakhs(salary_str.split('-')[0])
        max_sal = get_number_in_lakhs(salary_str.split('-')[1])
        avg_sal = (min_sal + max_sal)/2
    else:
        avg_sal = get_number_in_lakhs(salary_str)
    return avg_sal
        
def get_number_in_lakhs(num: str) -> int:
    if 'L' in num:
        return int(num.replace('L', ''))
    elif 'T' in num:
        return int(num.replace('T', '')) * 0.01
    elif 'Cr' in num:
        return int(num.replace('Cr', '')) * 100
    else:
        return int(num)

# %%
data['avg_salary_in_lakh'] = data['Salary Estimate'].apply(lambda x: get_avg_salary_in_lakhs(x))

# %%
data.head()
# Out:
#                          Job Title Salary Estimate  \
# 1  Assistant Data Science Engineer         7L - 8L
# 2                   Data Scientist         6L - 8L
# 4                   Data Analytics         4L - 7L
# 5              Data Science Intern       12T - 21T
# 6     A&A -Data Scientist - AI POD         5L - 9L
#
#                                      Job Description  Rating  \
# 1  Established in 2007, Educate Girls’ is a non-p...     3.9
# 2  About Us\n\nRamSoft is a global leader in Web ...     3.8
# 4  Job Description\n\n\n\n\nDomain\n\n\nData Anal...     3.7
# 5  ABOUT COTO\ncoto is a strong, growing deep tec...     4.3
# 6  Data Scientist- Staff\nDo you have a passion f...     4.1
#
#                     Company Name   Location                    Size  Founded  \
# 1             Educate Girls\n3.9     Mumbai  1001 to 5000 Employees       -1
# 2                   RamSoft\n3.8  Bengaluru     51 to 200 Employees     1994
# 4  Tata Technologies Europe\n3.7       Pune        10000+ Employees     1989
# 5                      Coto\n4.3     Mumbai     51 to 200 Employees     2021
# 6                  Deloitte\n4.1  Bengaluru        10000+ Employees     1850
#
#    Type of ownership                Industry                   Sector  \
# 1  Company - Private                      -1                       -1
# 2  Company - Private    Software Development   Information Technology
# 4  Company - Private  Research & Development  Management & Consulting
# 5  Company - Private    Software Development   Information Technology
# 6  Company - Private        Accounting & Tax                  Finance
#
#                       Revenue  Competitors  Employer Provided Salary  \
# 1    Unknown / Non-Applicable           -1                         1
# 2    Unknown / Non-Applicable           -1                         0
# 4  $100 to $500 million (USD)           -1                         0
# 5    Unknown / Non-Applicable           -1                         1
# 6    Unknown / Non-Applicable           -1                         0
#
#    avg_salary_in_lakh
# 1               7.500
# 2               7.000
# 4               5.500
# 5               0.165
# 6               7.000

# %%
# Company name text only
data['Company Name'] = data[['Company Name', 'Rating']].apply(lambda x: x['Company Name'] if x['Rating'] <0 else x['Company Name'][:-4], axis=1)

# %%
data.head()
# Out:
#                          Job Title Salary Estimate  \
# 1  Assistant Data Science Engineer         7L - 8L
# 2                   Data Scientist         6L - 8L
# 4                   Data Analytics         4L - 7L
# 5              Data Science Intern       12T - 21T
# 6     A&A -Data Scientist - AI POD         5L - 9L
#
#                                      Job Description  Rating  \
# 1  Established in 2007, Educate Girls’ is a non-p...     3.9
# 2  About Us\n\nRamSoft is a global leader in Web ...     3.8
# 4  Job Description\n\n\n\n\nDomain\n\n\nData Anal...     3.7
# 5  ABOUT COTO\ncoto is a strong, growing deep tec...     4.3
# 6  Data Scientist- Staff\nDo you have a passion f...     4.1
#
#                Company Name   Location                    Size  Founded  \
# 1             Educate Girls     Mumbai  1001 to 5000 Employees       -1
# 2                   RamSoft  Bengaluru     51 to 200 Employees     1994
# 4  Tata Technologies Europe       Pune        10000+ Employees     1989
# 5                      Coto     Mumbai     51 to 200 Employees     2021
# 6                  Deloitte  Bengaluru        10000+ Employees     1850
#
#    Type of ownership                Industry                   Sector  \
# 1  Company - Private                      -1                       -1
# 2  Company - Private    Software Development   Information Technology
# 4  Company - Private  Research & Development  Management & Consulting
# 5  Company - Private    Software Development   Information Technology
# 6  Company - Private        Accounting & Tax                  Finance
#
#                       Revenue  Competitors  Employer Provided Salary  \
# 1    Unknown / Non-Applicable           -1                         1
# 2    Unknown / Non-Applicable           -1                         0
# 4  $100 to $500 million (USD)           -1                         0
# 5    Unknown / Non-Applicable           -1                         1
# 6    Unknown / Non-Applicable           -1                         0
#
#    avg_salary_in_lakh
# 1               7.500
# 2               7.000
# 4               5.500
# 5               0.165
# 6               7.000

# %%
# Age of the Company
data['company_age'] = data['Founded'].apply(lambda x: x if x<1 else 2023 - x)

# %%
# import spacy
# import en_core_web_md
# nlp = spacy.load("en_core_web_md")

# data['jd_keywords'] = data['Job Description'].apply(lambda x: nlp(x).ents)

# %%
# checking for keywords in job description

#python
data['python_req'] = data['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)

#excel
data['excel'] = data['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() or 'ms-excel' in x.lower() else 0)

#aws
data['aws'] = data['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)

#spark
data['spark'] = data['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)

# %%
data.head()
# Out:
#                          Job Title Salary Estimate  \
# 1  Assistant Data Science Engineer         7L - 8L
# 2                   Data Scientist         6L - 8L
# 4                   Data Analytics         4L - 7L
# 5              Data Science Intern       12T - 21T
# 6     A&A -Data Scientist - AI POD         5L - 9L
#
#                                      Job Description  Rating  \
# 1  Established in 2007, Educate Girls’ is a non-p...     3.9
# 2  About Us\n\nRamSoft is a global leader in Web ...     3.8
# 4  Job Description\n\n\n\n\nDomain\n\n\nData Anal...     3.7
# 5  ABOUT COTO\ncoto is a strong, growing deep tec...     4.3
# 6  Data Scientist- Staff\nDo you have a passion f...     4.1
#
#                Company Name   Location                    Size  Founded  \
# 1             Educate Girls     Mumbai  1001 to 5000 Employees       -1
# 2                   RamSoft  Bengaluru     51 to 200 Employees     1994
# 4  Tata Technologies Europe       Pune        10000+ Employees     1989
# 5                      Coto     Mumbai     51 to 200 Employees     2021
# 6                  Deloitte  Bengaluru        10000+ Employees     1850
#
#    Type of ownership                Industry                   Sector  \
# 1  Company - Private                      -1                       -1
# 2  Company - Private    Software Development   Information Technology
# 4  Company - Private  Research & Development  Management & Consulting
# 5  Company - Private    Software Development   Information Technology
# 6  Company - Private        Accounting & Tax                  Finance
#
#                       Revenue  Competitors  Employer Provided Salary  \
# 1    Unknown / Non-Applicable           -1                         1
# 2    Unknown / Non-Applicable           -1                         0
# 4  $100 to $500 million (USD)           -1                         0
# 5    Unknown / Non-Applicable           -1                         1
# 6    Unknown / Non-Applicable           -1                         0
#
#    avg_salary_in_lakh  company_age  python_req  excel  aws  spark
# 1               7.500           -1           0      0    0      0
# 2               7.000           29           0      0    0      0
# 4               5.500           34           0      0    0      0
# 5               0.165            2           0      0    0      0
# 6               7.000          173           0      0    0      0

# %%
data['python_req'].value_counts()
# Out:
# 0    28
# 1     7
# Name: python_req, dtype: int64
